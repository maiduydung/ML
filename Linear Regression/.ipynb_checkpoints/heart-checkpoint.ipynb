# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import feature_column
from tensorflow import data, convert_to_tensor
from tensorflow.keras import  layers, Sequential, losses
from tensorflow.keras.callbacks import EarlyStopping


from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../datasets/heart-disease/heart.csv')
display(df)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
df.hist(figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'ca'}>,
#         <AxesSubplot:title={'center':'chol'}>,
#         <AxesSubplot:title={'center':'cp'}>],
#        [<AxesSubplot:title={'center':'exang'}>,
#         <AxesSubplot:title={'center':'fbs'}>,
#         <AxesSubplot:title={'center':'oldpeak'}>,
#         <AxesSubplot:title={'center':'restecg'}>],
#        [<AxesSubplot:title={'center':'sex'}>,
#         <AxesSubplot:title={'center':'slope'}>,
#         <AxesSubplot:title={'center':'target'}>,
#         <AxesSubplot:title={'center':'thal'}>],
#        [<AxesSubplot:title={'center':'thalach'}>,
#         <AxesSubplot:title={'center':'trestbps'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
train, test = train_test_split(df, test_size = 0.2)
train, val  = train_test_split(train, test_size = 0.2)
print(train.shape)
print(val.shape)
print(test.shape)
# Out:
# (656, 14)
# (164, 14)
# (205, 14)

# %%
#wraping dataframe with tf.data
def df_to_dataset(df, shuffle = True, batch_size = 32):
    dataframe = df.copy()
    labels = df.pop('target')
    ds = data.Dataset.from_tensor_slices((dict(dataframe), labels))
    if shuffle:
        ds = ds.shuffle(buffer_size=len(dataframe))
    ds = ds.batch(batch_size)
    return ds

# %%
batch_size = 5
train_ds = df_to_dataset(train, batch_size = batch_size)
val_ds = df_to_dataset(val, batch_size = batch_size)
test_ds = df_to_dataset(test, batch_size = batch_size)

# %%
features = []
for f in list(df.columns):
    features.append(feature_column.numeric_column(f))
features
# Out:
# [NumericColumn(key='age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='sex', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='cp', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='trestbps', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='chol', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='fbs', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='restecg', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='thalach', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='exang', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='oldpeak', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='slope', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='ca', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='thal', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='target', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %%
feature_layer = layers.DenseFeatures(features)

# %%
#early_stopping
es_cb = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto')

# %%
model = Sequential([
    feature_layer,
    layers.Dense(128, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dropout(.1),
    layers.Dense(1)
])
model.compile(optimizer='adam', loss=losses.BinaryCrossentropy(from_logits=True), metrics=['accuracy'])

model.fit(train_ds, validation_data=val_ds, epochs=200, callbacks=[es_cb])
# Out:
# Train for 132 steps, validate for 33 steps
# Epoch 1/200
# 132/132 [==============================] - 1s 10ms/step - loss: 4.0807 - accuracy: 0.5655 - val_loss: 0.8485 - val_accuracy: 0.7073
# Epoch 2/200
# 132/132 [==============================] - 0s 2ms/step - loss: 1.9443 - accuracy: 0.6296 - val_loss: 0.4560 - val_accuracy: 0.8110
# Epoch 3/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.9527 - accuracy: 0.6646 - val_loss: 0.3873 - val_accuracy: 0.8293
# Epoch 4/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.5302 - accuracy: 0.7652 - val_loss: 0.3240 - val_accuracy: 0.8780
# Epoch 5/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.4939 - accuracy: 0.7729 - val_loss: 0.2634 - val_accuracy: 0.8963
# Epoch 6/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.4334 - accuracy: 0.7988 - val_loss: 0.2666 - val_accuracy: 0.9024
# Epoch 7/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.3691 - accuracy: 0.8262 - val_loss: 0.2803 - val_accuracy: 0.8354
# Epoch 8/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.3588 - accuracy: 0.8369 - val_loss: 0.2187 - val_accuracy: 0.8902
# Epoch 9/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.3322 - accuracy: 0.8415 - val_loss: 0.2731 - val_accuracy: 0.8963
# Epoch 10/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.3564 - accuracy: 0.8689 - val_loss: 0.3237 - val_accuracy: 0.8963
# Epoch 11/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.2378 - accuracy: 0.9009 - val_loss: 0.1740 - val_accuracy: 0.9451
# Epoch 12/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.1902 - accuracy: 0.9253 - val_loss: 0.3262 - val_accuracy: 0.7744
# Epoch 13/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.1963 - accuracy: 0.9314 - val_loss: 0.1531 - val_accuracy: 0.9146
# Epoch 14/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.1891 - accuracy: 0.9223 - val_loss: 0.1706 - val_accuracy: 0.8841
# Epoch 15/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.2399 - accuracy: 0.8933 - val_loss: 0.2561 - val_accuracy: 0.9207
# Epoch 16/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.1466 - accuracy: 0.9497 - val_loss: 0.1284 - val_accuracy: 0.9573
# Epoch 17/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.1686 - accuracy: 0.9329 - val_loss: 0.1172 - val_accuracy: 0.9695
# Epoch 18/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.1159 - accuracy: 0.9497 - val_loss: 0.1418 - val_accuracy: 0.9146
# Epoch 19/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.1021 - accuracy: 0.9634 - val_loss: 0.1012 - val_accuracy: 0.9695
# Epoch 20/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.0855 - accuracy: 0.9649 - val_loss: 0.0322 - val_accuracy: 0.9878
# Epoch 21/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0652 - accuracy: 0.9756 - val_loss: 0.0240 - val_accuracy: 1.0000
# Epoch 22/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0513 - accuracy: 0.9848 - val_loss: 0.0319 - val_accuracy: 0.9939
# Epoch 23/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.0350 - accuracy: 0.9893 - val_loss: 0.0268 - val_accuracy: 0.9878
# Epoch 24/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0302 - accuracy: 0.9909 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 25/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 0.9970 - val_loss: 0.0173 - val_accuracy: 1.0000
# Epoch 26/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0255 - accuracy: 0.9939 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 27/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.0611 - accuracy: 0.9832 - val_loss: 0.2353 - val_accuracy: 0.9146
# Epoch 28/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.0679 - accuracy: 0.9771 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 29/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 30/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0076 - accuracy: 0.9985 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 31/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 32/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 33/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 34/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 35/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 36/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 37/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 38/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 39/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 40/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 41/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 42/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 43/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 44/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 6.1029e-04 - val_accuracy: 1.0000
# Epoch 45/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 7.9425e-04 - val_accuracy: 1.0000
# Epoch 46/200
# 132/132 [==============================] - 0s 3ms/step - loss: 8.9572e-04 - accuracy: 1.0000 - val_loss: 4.3627e-04 - val_accuracy: 1.0000
# Epoch 47/200
# 132/132 [==============================] - 0s 3ms/step - loss: 8.7399e-04 - accuracy: 1.0000 - val_loss: 4.5980e-04 - val_accuracy: 1.0000
# Epoch 48/200
# 132/132 [==============================] - 0s 2ms/step - loss: 7.1336e-04 - accuracy: 1.0000 - val_loss: 3.2814e-04 - val_accuracy: 1.0000
# Epoch 49/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.4178 - accuracy: 0.8933 - val_loss: 0.1207 - val_accuracy: 0.9939
# Epoch 50/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.2023 - accuracy: 0.9146 - val_loss: 0.0498 - val_accuracy: 0.9878
# Epoch 51/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0922 - accuracy: 0.9756 - val_loss: 0.0157 - val_accuracy: 1.0000
# Epoch 52/200
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0532 - accuracy: 0.9832 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 53/200
# 132/132 [==============================] - 0s 2ms/step - loss: 0.0265 - accuracy: 0.9954 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 00053: early stopping

# %%
model.evaluate(test_ds)
# Out:
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0049 - accuracy: 1.0000
# [0.004867630892876172, 1.0]

# %%
model.save('heart_disease_classifier')
# Out:
# WARNING:tensorflow:From C:\Users\iniad\miniconda3\envs\ds2020\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: heart_disease_classifier\assets

# %%
sample = {
    'age'    : 70,
    'sex'    : 1,
    'cp'     : 1,
    'trestbpd' : 200,
    'chol'   : 100,
    'fbs'    : 0,
    'restecg': 2,
    'thalach': 200,
    'exang'  : 0,
    'oldpeak': 6,
    'slope'  : 2,
    'ca'     : 1,
    'thal'   : 3    
}
input_dict = {name: convert_to_tensor([val]) for name, val in sample.items()}
pred = model.predict()
