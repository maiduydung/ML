# %%
import numpy as np
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

from scipy.spatial import distance

# %% [markdown]
# ### Edge detection

# %%
img = cv.imread('skulls/Angolan Colobus Monkey_Colobus angolensis.jpg',0)
edges = cv.Canny(img,100,900)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
edges = np.array(edges)
edges.shape
# Out:
# (397, 479)

# %%
center = [x//2 for x in edges.shape]
center
# Out:
# [198, 239]

# %% [markdown]
# ### Euclidean distance

# %% [markdown]
# ![image.png](attachment:52f7c13b-988b-4a3a-a76a-9bfad0842e49.png)

# %%
a = (1, 2)
b = (4, 5)
dst = distance.euclidean(a, b)
dst
# Out:
# 4.242640687119285
