# %% [markdown]
# #### Random Walk

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Generate 500 random White Noise steps with mean=0 and standard deviation=1
steps = np.random.normal(loc=0, scale=1, size=500)

# Set first element to 0 so that the first price will be the starting stock price
steps[0]=0

P = 100 + np.cumsum(steps)

plt.plot(P)
plt.title('Random walk')
# Out:
# Text(0.5, 1.0, 'Random walk')

# %%
plt.plot(steps)
plt.title('White Noise term')
# Out:
# Text(0.5, 1.0, 'White Noise term')

# %% [markdown]
# #### Random Walk with drift

# %%
mu = -0.01
steps = np.random.normal(loc=0, scale=1, size=500) + mu

# Set first element to 0
steps[0]=0

# Simulate the stock price
P = 100 + np.cumsum(steps) 

# Plot the simulated stock prices
plt.plot(P)
plt.title("Random Walk with Drift")
plt.show()

# %%
# Generate 500 random steps
steps = np.random.normal(loc=0.001, scale=0.01, size=500) + 1

# Set first element to 1
steps[0]=1

# Simulate the stock price, P, by taking the cumulative product
P = 100 * np.cumprod(steps)

# Plot the simulated stock prices
plt.plot(P)
plt.title("Simulated Random Walk with Drift")
plt.show()

# %%
plt.plot(steps)
