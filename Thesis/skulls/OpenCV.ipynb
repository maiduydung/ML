# %%
import numpy as np
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

from scipy.spatial import distance

# %% [markdown]
# ### Edge detection

# %%
img = cv.imread('skulls/Aye-Aye          Daubentonia madagascarensis.jpg',0)
edges = cv.Canny(img,100,500)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
edges = np.array(edges)
edges.shape
# Out:
# (230, 219)

# %%
center = [x//2 for x in edges.shape]
center
# Out:
# [115, 109]

# %% [markdown]
# ### Look for index with value = 255 <=> have a dot

# %%
shape_arr = np.array(np.where (edges == 255))
print(shape_arr.shape)
shape_arr
# Out:
# (2, 4552)
# array([[ 45,  45,  45, ..., 183, 183, 183],
#        [104, 105, 106, ..., 102, 103, 104]], dtype=int64)

# %%
#print(edges[4,299]) #debug
#print(edges[4,300]) #debug

# %% [markdown]
# ### Euclidean distance from center to point with value = 255

# %%
series = []
for i in range(0,(shape_arr.shape[1])):
    dst = distance.euclidean(center, shape_arr[:,i])
    series.append(dst)
series = np.array(series)
series
# Out:
# array([70.17834424, 70.11419257, 70.06425622, ..., 68.35934464,
#        68.26419266, 68.18357573])

# %% [markdown]
# ### Too much noise

# %%
img = cv.imread('hand drawn/Aye-Aye          Daubentonia madagascarensis.jpg',0)
edges = cv.Canny(img,0,10)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
edges = np.array(edges)
edges.shape
# Out:
# (1200, 1920)

# %%
center = [x//2 for x in edges.shape]
center
# Out:
# [600, 960]

# %%
shape_arr = np.array(np.where (edges == 255))
print(shape_arr.shape)
shape_arr
# Out:
# (2, 6225)
# array([[ 256,  256,  256, ...,  936,  936,  936],
#        [1057, 1058, 1059, ...,  679,  680,  681]], dtype=int64)

# %%
series = []
for i in range(0,(shape_arr.shape[1])):
    dst = distance.euclidean(center, shape_arr[:,i])
    series.append(dst)
series = np.array(series)
series
# Out:
# array([357.4143254 , 357.68701402, 357.96228852, ..., 438.01483993,
#        437.37398185, 436.73447311])

# %% [markdown]
# ### Euclidean distance

# %% [markdown]
# ![image.png](attachment:52f7c13b-988b-4a3a-a76a-9bfad0842e49.png)

# %%
a = (1, 2)
b = (4, 5)
dst = distance.euclidean(a, b)
dst
# Out:
# 4.242640687119285
