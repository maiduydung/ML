# %%
import numpy as np
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

from scipy.spatial import distance

# %% [markdown]
# ### Edge detection

# %%
img = cv.imread('skulls/Aye-Aye          Daubentonia madagascarensis.jpg',0)
edges = cv.Canny(img,100,500)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
edges = np.array(edges)
edges.shape
# Out:
# (397, 479)

# %%
center = [x//2 for x in edges.shape]
center
# Out:
# [198, 239]

# %% [markdown]
# ### Look for index with value = 255 <=> have a dot

# %%
shape_arr = np.array(np.where (edges == 255))
print(shape_arr.shape)
shape_arr
# Out:
# (2, 2109)
# array([[  4,   4,   4, ..., 392, 392, 392],
#        [299, 300, 301, ..., 161, 162, 163]], dtype=int64)

# %%
#print(edges[4,299]) #debug
#print(edges[4,300]) #debug

# %% [markdown]
# ### Euclidean distance from center to point with value = 255

# %%
series = []
for i in range(0,(shape_arr.shape[1])):
    dst = distance.euclidean(center, shape_arr[:,i])
    series.append(dst)
series = np.array(series)
series
# Out:
# array([203.06649157, 203.36420531, 203.66639389, ..., 209.09328062,
#        208.72230355, 208.35546549])

# %% [markdown]
# ### DTW

# %%
img = cv.imread('skulls_testset/Angolan Colobus Monkey_Colobus angolensis.jpg',0)
edges = cv.Canny(img,50,400)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### Euclidean distance

# %% [markdown]
# ![image.png](attachment:52f7c13b-988b-4a3a-a76a-9bfad0842e49.png)

# %%
a = (1, 2)
b = (4, 5)
dst = distance.euclidean(a, b)
dst
# Out:
# 4.242640687119285
