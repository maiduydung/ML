# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure


import random as rnd


import seaborn as sns
from sklearn.linear_model import LinearRegression
from pandas.tseries.offsets import DateOffset
from datetime import timedelta
from statsmodels.tsa.ar_model import AutoReg

# %matplotlib inline

# %%
diet_df = pd.read_csv('../datasets/time_series/diet_search.csv')
diet_df.index = pd.to_datetime(diet_df['Month'])
diet_df = diet_df.drop("Month", axis = 1)
diet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 207 entries, 2004-01-01 to 2021-03-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   rate    207 non-null    int64
# dtypes: int64(1)
# memory usage: 3.2 KB

# %%
diet_df
# Out:
#             rate
# Month
# 2004-01-01   100
# 2004-02-01    78
# 2004-03-01    71
# 2004-04-01    69
# 2004-05-01    74
# ...          ...
# 2020-11-01    34
# 2020-12-01    32
# 2021-01-01    42
# 2021-02-01    40
# 2021-03-01    40
#
# [207 rows x 1 columns]

# %%
diet_df.columns
# Out:
# Index(['rate'], dtype='object')

# %%
figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')
plt.plot(diet_df.index, diet_df['rate'])

# %%
figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')
plt.plot(diet_df.index, diet_df['rate'].pct_change())
plt.title('Percentage change')
# Out:
# Text(0.5, 1.0, 'Percentage change')

# %%
#always check correlation by their percent changes

x = np.random.rand(100)
y = np.random.rand(100)

xy = {'col1': x, 'col2':y}
xy = pd.DataFrame(data=xy)

print("Correlation by level ",xy['col1'].corr(xy['col2']))

changes = xy.pct_change()
print("Correlation by percent changes ", changes['col1'].corr(changes['col2']))
# Out:
# Correlation by level  -0.03170157082613387
# Correlation by percent changes  -0.10846894768862149

# %% [markdown]
# ### Correlation by level vs percent changes

# %%
#grabbing 2012 and 2013 search rate
diet2012 = diet_df.loc['2012']
diet2013 = diet_df.loc['2013']
diet2012 = diet2012.reset_index()
diet2013 = diet2013.reset_index()
diet_test = {'col2012': diet2012['rate'], 'col2013':diet2013['rate']}
diet_test = pd.DataFrame(data=diet_test)
diet_test
# Out:
#     col2012  col2013
# 0        66       65
# 1        57       59
# 2        57       58
# 3        59       60
# 4        56       57
# 5        53       56
# 6        56       54
# 7        55       53
# 8        53       50
# 9        47       50
# 10       47       46
# 11       42       41

# %%
plt.plot(diet_test['col2012'], label="2012")
plt.plot(diet_test['col2013'], label="2013")
plt.legend()

# %%
print("Correlation by level ",diet_test['col2012'].corr(diet_test['col2013']))

changes = diet_test.pct_change()
print("Correlation by percent changes ", changes['col2012'].corr(changes['col2013']))
# Out:
# Correlation by level  0.9517850986192126
# Correlation by percent changes  0.46614433450612935

# %% [markdown]
# ##### There may be high correlation by level between 2 process, however, they may or nay not related to eachother
# ##### In this particular case, they do related to each other

# %%
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
#series = read_csv('daily-minimum-temperatures.csv', header=0, index_col=0)
plot_acf(diet_df['rate'])
plot_pacf(diet_df['rate'])
pyplot.show()
# temperatures are heavily correlated, especially every 12 month (obviously)

# %% [markdown]
# ### Linear Regression
# ##### It is obvious that lin reg is not the best choice in time series forcasting, this is just a demo on the entire dataset
# ##### Which is badly effected by outliners and can not represent sine wave-like flucuations

# %%
diet_df = pd.read_csv('../datasets/time_series/diet_search.csv')
diet_df.index = pd.to_datetime(diet_df['Month'])
diet_df = diet_df.drop("Month", axis = 1)
diet_df.index = diet_df.index.to_julian_date() #converting from datetime to numerical for linear regression
diet_df
# Out:
#            rate
# Month
# 2453005.5   100
# 2453036.5    78
# 2453065.5    71
# 2453096.5    69
# 2453126.5    74
# ...         ...
# 2459154.5    34
# 2459184.5    32
# 2459215.5    42
# 2459246.5    40
# 2459274.5    40
#
# [207 rows x 1 columns]

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
#X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])
# y = 1 * x_0 + 2 * x_1 + 3
#y = np.dot(X, np.array([1, 2])) + 3
X = np.array(diet_df.index).reshape(-1,1) #2d array
y = diet_df['rate']


reg = LinearRegression().fit(X, y)
print("score",reg.score(X, y))
print('coef',reg.coef_)
print('intercept',reg.intercept_)

plt.scatter(X,y)
plt.plot(X, reg.predict(X),color='r')
# Out:
# score 0.1310681073023937
# coef [-0.00165437]
# intercept 4113.165150398642

# %% [markdown]
# #### Linear Regression for each year separately, however, is a good solution to predict the outcome

# %%
diet_df = pd.read_csv('../datasets/time_series/diet_search.csv')
diet_df.index = pd.to_datetime(diet_df['Month'])
diet_df = diet_df.drop("Month", axis = 1)
#diet_df.index = diet_df.index.to_julian_date() #converting from datetime to numerical for linear regression
diet2012 = diet_df.loc['2012']
diet2013 = diet_df.loc['2013']
diet2012.index = diet2012.index.to_julian_date()
diet2013.index = diet2013.index.to_julian_date()

# %%
#2012

X = np.array(diet2012.index).reshape(-1,1) #2d array
y = diet2012['rate']

reg = LinearRegression().fit(X, y)

print("score",reg.score(X, y))
print('coef',reg.coef_)
print('intercept',reg.intercept_)

plt.scatter(X,y)
plt.plot(X, reg.predict(X),color='r')
# Out:
# score 0.8191543250261692
# coef [-0.05206991]
# intercept 127942.63195255886

# %%
#2013

X = np.array(diet2013.index).reshape(-1,1) #2d array
y = diet2013['rate']

reg = LinearRegression().fit(X, y)

print("score",reg.score(X, y))
print('coef',reg.coef_)
print('intercept',reg.intercept_)

plt.scatter(X,y)
plt.plot(X, reg.predict(X),color='r')
# Out:
# score 0.9208835497910571
# coef [-0.05760933]
# intercept 141569.0934972405

# %% [markdown]
# #### Predicting with an AR(13) model

# %%
y = diet_df['rate']

# %%
from statsmodels.tsa.ar_model import AutoReg
model = AutoReg(y, lags=13, trend='n', seasonal = True, period = 24)
results = model.fit()
results.summary()
# Out:
# C:\Users\maidu\.conda\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\maidu\.conda\envs\tf\lib\site-packages\statsmodels\tsa\ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                   rate   No. Observations:                  207
# Model:              Seas. AutoReg(13)   Log Likelihood                -413.871
# Method:               Conditional MLE   S.D. of innovations              2.043
# Date:                Fri, 30 Jul 2021   AIC                              1.821
# Time:                        22:04:46   BIC                              2.461
# Sample:                    02-01-2005   HQIC                             2.080
#                          - 03-01-2021
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# seasonal.0     14.2602      2.514      5.673      0.000       9.333      19.187
# seasonal.1      3.4796      2.433      1.430      0.153      -1.289       8.248
# seasonal.2      1.3022      2.371      0.549      0.583      -3.346       5.950
# seasonal.3      4.0280      2.465      1.634      0.102      -0.803       8.859
# seasonal.4      6.7802      2.440      2.778      0.005       1.997      11.564
# seasonal.5      2.2258      2.460      0.905      0.365      -2.595       7.046
# seasonal.6      2.1141      2.462      0.859      0.390      -2.711       6.939
# seasonal.7      3.2090      2.466      1.301      0.193      -1.624       8.042
# seasonal.8      0.3892      2.475      0.157      0.875      -4.463       5.241
# seasonal.9     -0.5326      2.406     -0.221      0.825      -5.247       4.182
# seasonal.10    -5.8023      2.395     -2.423      0.015     -10.496      -1.108
# seasonal.11    -3.3499      2.423     -1.382      0.167      -8.099       1.399
# seasonal.12    14.6024      2.426      6.018      0.000       9.847      19.358
# seasonal.13     4.3494      2.446      1.778      0.075      -0.444       9.143
# seasonal.14     3.7422      2.349      1.593      0.111      -0.863       8.347
# seasonal.15     5.8972      2.519      2.341      0.019       0.960      10.834
# seasonal.16     6.0352      2.519      2.396      0.017       1.097      10.973
# seasonal.17     2.0117      2.543      0.791      0.429      -2.972       6.996
# seasonal.18     1.4708      2.555      0.576      0.565      -3.537       6.478
# seasonal.19     3.2694      2.558      1.278      0.201      -1.744       8.283
# seasonal.20    -0.0817      2.566     -0.032      0.975      -5.111       4.947
# seasonal.21     0.5590      2.489      0.225      0.822      -4.320       5.438
# seasonal.22    -6.5315      2.483     -2.630      0.009     -11.398      -1.664
# seasonal.23    -4.2407      2.513     -1.688      0.091      -9.165       0.684
# rate.L1         0.5166      0.069      7.450      0.000       0.381       0.653
# rate.L2         0.1816      0.078      2.314      0.021       0.028       0.335
# rate.L3         0.0543      0.081      0.669      0.503      -0.105       0.213
# rate.L4        -0.0808      0.081     -0.994      0.320      -0.240       0.079
# rate.L5         0.1511      0.081      1.856      0.063      -0.008       0.311
# rate.L6         0.0893      0.082      1.089      0.276      -0.071       0.250
# rate.L7        -0.0159      0.082     -0.194      0.847      -0.177       0.145
# rate.L8         0.0658      0.082      0.802      0.422      -0.095       0.227
# rate.L9         0.0297      0.080      0.373      0.709      -0.126       0.186
# rate.L10        0.2627      0.079      3.342      0.001       0.109       0.417
# rate.L11       -0.1518      0.080     -1.888      0.059      -0.309       0.006
# rate.L12        0.0885      0.081      1.088      0.276      -0.071       0.248
# rate.L13       -0.2432      0.063     -3.858      0.000      -0.367      -0.120
#                                     Roots
# ==============================================================================
#                    Real          Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1             1.0398           -0.0000j            1.0398           -0.0000
# AR.2             1.1082           -0.0000j            1.1082           -0.0000
# AR.3             0.8420           -0.6503j            1.0639           -0.1047
# AR.4             0.8420           +0.6503j            1.0639            0.1047
# AR.5             0.4220           -1.0135j            1.0978           -0.1872
# AR.6             0.4220           +1.0135j            1.0978            0.1872
# AR.7            -1.0633           -0.0000j            1.0633           -0.5000
# AR.8            -0.9072           -0.5861j            1.0801           -0.4087
# AR.9            -0.9072           +0.5861j            1.0801            0.4087
# AR.10           -0.5848           -1.0004j            1.1588           -0.3342
# AR.11           -0.5848           +1.0004j            1.1588            0.3342
# AR.12           -0.1324           -1.2462j            1.2532           -0.2668
# AR.13           -0.1324           +1.2462j            1.2532            0.2668
# ------------------------------------------------------------------------------
# """

# %%
figure(figsize=(14, 4), dpi=80)
y_pred = results.predict(end=215)
plt.plot(y, label='Observed',linewidth=3)
plt.plot(y_pred, label = 'Predict', linewidth=1)
plt.title("Diet search interest prediction")
plt.legend()
# Out:
# C:\Users\maidu\.conda\envs\tf\lib\site-packages\statsmodels\tsa\deterministic.py:147: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Int64Indexes with a unit increment support extending. The index is set will contain the position relative to the data length.
#   warnings.warn(

# %%
y_pred[200:]
# Out:
# 2020-09-01    38.959298
# 2020-10-01    37.499296
# 2020-11-01    34.771067
# 2020-12-01    30.617697
# 2021-01-01    46.809748
# 2021-02-01    39.851234
# 2021-03-01    40.769430
# 2021-04-01    45.290194
# 2021-05-01    46.220498
# 2021-06-01    43.515971
# 2021-07-01    41.545532
# 2021-08-01    40.800269
# 2021-09-01    36.901966
# 2021-10-01    36.917193
# 2021-11-01    31.839143
# 2021-12-01    29.905290
# Freq: MS, dtype: float64

# %%
y.index
# Out:
# DatetimeIndex(['2004-01-01', '2004-02-01', '2004-03-01', '2004-04-01',
#                '2004-05-01', '2004-06-01', '2004-07-01', '2004-08-01',
#                '2004-09-01', '2004-10-01',
#                ...
#                '2020-06-01', '2020-07-01', '2020-08-01', '2020-09-01',
#                '2020-10-01', '2020-11-01', '2020-12-01', '2021-01-01',
#                '2021-02-01', '2021-03-01'],
#               dtype='datetime64[ns]', name='Month', length=207, freq=None)
