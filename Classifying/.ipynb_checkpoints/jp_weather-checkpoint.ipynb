# %%
import pandas as pd
import random as rnd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
df = pd.read_csv('../datasets/weather/jp_weather.csv',decimal=",")
df = df.drop('Value', axis = 1)
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values(by=["Date"])
df['Celsius'] = pd.to_numeric(df['Celsius'])
df['Celsius'] = df['Celsius'].round(2)

# %%
#saving latitude and longitude to a list of dictionary
stations = df['Station'].unique()
Positions = []
for station in stations:
    #display(station ,df[df['Station'] == station][['LAT']][:1].values[0][0])
    Positions.append({'loc':[df[df['Station'] == station][['LAT']][:1].values[0][0], df[df['Station'] == station][['LON']][:1].values[0][0]],
                      'station':station})

# %%
# Making a map using the folium module
import folium
jp_map = folium.Map()

# Adding markers to the map
for position in Positions:
    marker = folium.Marker(location=position['loc'], popup=position['station']+" STATION")
    marker.add_to(jp_map)

# The last object in the cell always gets shown in the notebook
jp_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_27f1d8dd1b954480a3821889fe3e9ea8%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_27f1d8dd1b954480a3821889fe3e9ea8%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_27f1d8dd1b954480a3821889fe3e9ea8%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_27f1d8dd1b954480a3821889fe3e9ea8%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %%
# Japan mean temperature 
df.describe()
# Out:
#              Celsius
# count  100000.000000
# mean       15.402511
# std         9.177219
# min       -17.390000
# 25%         8.560000
# 50%        16.110000
# 75%        22.940000
# max        35.890000

# %% [markdown]
# #### Tokyo International Airport

# %%
tokyo_intl_df =  df[df['Station']=='TOKYO INTL'] 
tokyo_intl_df.describe()
# Out:
#            Celsius
# count  1000.000000
# mean     17.345110
# std       7.691579
# min       1.560000
# 25%      10.390000
# 50%      17.280000
# 75%      23.780000
# max      31.610000

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')
plt.plot(tokyo_intl_df['Date'], tokyo_intl_df['Celsius'])
plt.xlabel('Time')
plt.ylabel('Temperature (Celsius)')
plt.title('Tokyo International Airport mean temp')
# Out:
# Text(0.5, 1.0, 'Tokyo International Airport mean temp')

# %% [markdown]
# #### Tokyo Heliport

# %%
tokyo_heliport_df =  df[df['Station']=='TOKYO HELIPORT'] 
tokyo_heliport_df.describe()
# Out:
#            Celsius
# count  1000.000000
# mean     18.433080
# std       7.874053
# min       0.780000
# 25%      11.220000
# 50%      18.330000
# 75%      25.220000
# max      33.110000

# %%
figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')
plt.plot(tokyo_heliport_df['Date'], tokyo_heliport_df['Celsius'])
plt.title('Tokyo Heliport mean temp')
# Out:
# Text(0.5, 1.0, 'Tokyo Heliport mean temp')

# %%
from sklearn.model_selection import train_test_split
X = tokyo_heliport_df['Date']
y = tokyo_heliport_df['Celsius']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf
#series = read_csv('daily-minimum-temperatures.csv', header=0, index_col=0)
#y = np.random.rand(100)
plot_acf(y)
pyplot.show()

# temperatures are strongly correlated, past temps influence future temps.

# %%
tokyo_intl_df.index = pd.to_datetime(tokyo_intl_df["Date"])
tokyo_intl_df.drop(['Date'], axis=1)
tokyo_intl_df_2018
# Out:
#                Station                            Sub-Sector    Super Region  \
# Date
# 2018-06-13  TOKYO INTL  GLOBAL DAILY WEATHER HISTORICAL DATA  GLOBAL WEATHER
# 2018-06-14  TOKYO INTL  GLOBAL DAILY WEATHER HISTORICAL DATA  GLOBAL WEATHER
# 2018-06-15  TOKYO INTL  GLOBAL DAILY WEATHER HISTORICAL DATA  GLOBAL WEATHER
# 2018-06-16  TOKYO INTL  GLOBAL DAILY WEATHER HISTORICAL DATA  GLOBAL WEATHER
# 2018-06-17  TOKYO INTL  GLOBAL DAILY WEATHER HISTORICAL DATA  GLOBAL WEATHER
# ...                ...                                   ...             ...
# 2021-03-17  TOKYO INTL  GLOBAL DAILY WEATHER HISTORICAL DATA  GLOBAL WEATHER
# 2021-03-18  TOKYO INTL  GLOBAL DAILY WEATHER HISTORICAL DATA  GLOBAL WEATHER
# 2021-03-19  TOKYO INTL  GLOBAL DAILY WEATHER HISTORICAL DATA  GLOBAL WEATHER
# 2021-03-20  TOKYO INTL  GLOBAL DAILY WEATHER HISTORICAL DATA  GLOBAL WEATHER
# 2021-03-21  TOKYO INTL  GLOBAL DAILY WEATHER HISTORICAL DATA  GLOBAL WEATHER
#
#            Time Level Country     LON            Weather Statistics  \
# Date
# 2018-06-13      DAILY   JAPAN  139.78  MEAN TEMPERATURE FOR THE DAY
# 2018-06-14      DAILY   JAPAN  139.78  MEAN TEMPERATURE FOR THE DAY
# 2018-06-15      DAILY   JAPAN  139.78  MEAN TEMPERATURE FOR THE DAY
# 2018-06-16      DAILY   JAPAN  139.78  MEAN TEMPERATURE FOR THE DAY
# 2018-06-17      DAILY   JAPAN  139.78  MEAN TEMPERATURE FOR THE DAY
# ...               ...     ...     ...                           ...
# 2021-03-17      DAILY   JAPAN  139.78  MEAN TEMPERATURE FOR THE DAY
# 2021-03-18      DAILY   JAPAN  139.78  MEAN TEMPERATURE FOR THE DAY
# 2021-03-19      DAILY   JAPAN  139.78  MEAN TEMPERATURE FOR THE DAY
# 2021-03-20      DAILY   JAPAN  139.78  MEAN TEMPERATURE FOR THE DAY
# 2021-03-21      DAILY   JAPAN  139.78  MEAN TEMPERATURE FOR THE DAY
#
#                                      Source     LAT  Celsius
# Date
# 2018-06-13  WEATHER DATA CENTERS DAILY DATA  35.552    21.94
# 2018-06-14  WEATHER DATA CENTERS DAILY DATA  35.552    20.56
# 2018-06-15  WEATHER DATA CENTERS DAILY DATA  35.552    17.22
# 2018-06-16  WEATHER DATA CENTERS DAILY DATA  35.552    16.72
# 2018-06-17  WEATHER DATA CENTERS DAILY DATA  35.552    20.06
# ...                                     ...     ...      ...
# 2021-03-17  WEATHER DATA CENTERS DAILY DATA  35.552    13.11
# 2021-03-18  WEATHER DATA CENTERS DAILY DATA  35.552    12.94
# 2021-03-19  WEATHER DATA CENTERS DAILY DATA  35.552    13.11
# 2021-03-20  WEATHER DATA CENTERS DAILY DATA  35.552    15.61
# 2021-03-21  WEATHER DATA CENTERS DAILY DATA  35.552    17.11
#
# [1000 rows x 10 columns]

# %%
# Import the adfuller module from statsmodels
from statsmodels.tsa.stattools import adfuller

# Run the ADF test on the price series and print out the results
results = adfuller(tokyo_intl_df['Celsius'])
print(results)

# Just print out the p-value
print('The p-value of the test on prices is: ' + str(results[1]))

# H0: the series is non-stationary (there's strong seasonality within)
if results[1] < results[4]['5%']:
    print('Reject H0')
else:
    print("Cannot reject H0")
# Out:
# (-1.9286550796246564, 0.31870322499477444, 18, 981, {'1%': -3.4370334797663844, '5%': -2.8644907213150725, '10%': -2.568341114581742}, 4178.2575176931205)
# The p-value of the test on prices is: 0.31870322499477444
# Cannot reject H0

# %% [markdown]
# ### Rolling regression

# %%
x = np.arange(0,100)
y = (np.sin(x)+1)*10+2*x+np.random.rand(100)*5

points = 12
names = []
for i in range(points):
  names.append("a"+str(i))
ds = []
target = []
for i in range(points,len(x)-1):
  ds.append(y[i-points:i])
  target.append(y[i]) 
df = pd.DataFrame(np.array(ds),columns=names) 
dfy = df 
dfy["target"] = target

# %%
dfy[names]
# Out:
#             a0          a1          a2          a3          a4          a5  \
# 0    11.686715   21.144422   25.389226   21.725823   10.783799   12.521647
# 1    21.144422   25.389226   21.725823   10.783799   12.521647   20.775481
# 2    25.389226   21.725823   10.783799   12.521647   20.775481   31.356354
# 3    21.725823   10.783799   12.521647   20.775481   31.356354   37.644517
# 4    10.783799   12.521647   20.775481   31.356354   37.644517   34.451546
# ..         ...         ...         ...         ...         ...         ...
# 82  177.572286  188.425337  186.046220  181.508695  175.176109  179.712189
# 83  188.425337  186.046220  181.508695  175.176109  179.712189  190.566852
# 84  186.046220  181.508695  175.176109  179.712189  190.566852  200.201696
# 85  181.508695  175.176109  179.712189  190.566852  200.201696  202.436449
# 86  175.176109  179.712189  190.566852  200.201696  202.436449  194.023744
#
#             a6          a7          a8          a9         a10         a11
# 0    20.775481   31.356354   37.644517   34.451546   28.152263   26.386020
# 1    31.356354   37.644517   34.451546   28.152263   26.386020   30.006737
# 2    37.644517   34.451546   28.152263   26.386020   30.006737   43.571418
# 3    34.451546   28.152263   26.386020   30.006737   43.571418   49.699870
# 4    28.152263   26.386020   30.006737   43.571418   49.699870   50.779067
# ..         ...         ...         ...         ...         ...         ...
# 82  190.566852  200.201696  202.436449  194.023744  188.786329  190.088782
# 83  200.201696  202.436449  194.023744  188.786329  190.088782  197.618122
# 84  202.436449  194.023744  188.786329  190.088782  197.618122  210.435955
# 85  194.023744  188.786329  190.088782  197.618122  210.435955  214.428704
# 86  188.786329  190.088782  197.618122  210.435955  214.428704  212.457301
#
# [87 rows x 12 columns]

# %%
dfy['target'].shape
# Out:
# (87,)

# %%
dfy[names].shape
# Out:
# (87, 12)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(dfy[names],dfy["target"])
plt.plot(np.arange(len(df)),df["target"])
plt.plot(np.arange(len(df)),model.predict(dfy[names]))

# %%
last = dfy.iloc[-1]
prediction = []
n = []
for i in range(points-1):
  n.append(last["a"+str(i+1)])
n.append(last["target"])
n.append(model.predict(np.array(n).reshape(1,-1))[0])
prediction.append(n[-1])
for i in range(100):
  n = n[1:]
  n.append(model.predict(np.array(n).reshape(1,-1))[0])
  prediction.append(n[-1])

# %%
plt.plot(np.arange(len(dfy)),dfy["target"],c="green")
plt.plot(np.arange(len(dfy),len(dfy)+len(prediction)),prediction,c="red")
