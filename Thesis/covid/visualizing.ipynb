# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('2021_JP_Region_Mobility_Report.csv') #google
print(df.shape)
# Out:
# (11424, 15)

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
from matplotlib.pyplot import figure
figure(figsize=(30, 6), dpi=80)
plt.plot((range(len(df))), df['transit_stations_percent_change_from_baseline'])
#plt.xticks(df['date'][::2], rotation ='vertical')
plt.show()
